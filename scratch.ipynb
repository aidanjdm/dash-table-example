# %%
import pandas as pd

# %%
df = pd.read_csv('dc-breweries.csv')

# %%
df
# Out:
#                        Beer Name                                      Brewery  \
# 0     On The Wings Of Armageddon                          DC Brau Brewing Co.
# 1                    Solar Abyss                          DC Brau Brewing Co.
# 2                  Yonder Cities                          DC Brau Brewing Co.
# 3                    Oskar Blues                          DC Brau Brewing Co.
# 4                Kick.Kick.Snare  Right Proper Brewing Company - Shaw Brewpub
# 5                     Desolation                          3 Stars Brewing Co.
# 6  Diamonds, Fur Coat, Champagne  Right Proper Brewing Company - Shaw Brewpub
# 7                   Lost Weekend              Bluejacket / Arsenal Restaurant
# 8                   Space Reaper                          DC Brau Brewing Co.
# 9                        The Jam              Bluejacket / Arsenal Restaurant
#
#                    Style  Alcohol By Volume (ABV)  Ratings (Total)  \
# ...
